# %% [markdown]
# <a href="https://colab.research.google.com/github/psameni/Pranaya_INFO5731_Spring2020/blob/master/InClass_Excercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Rule-based information extraction
# Use any keywords related to data science, natural language processing, machine learning to search from google scholar, get the titles of 100 articles (either by web scraping or manually) about this topic, define a set of patterns to extract the research questions/problems, methods/algorithms/models, datasets, applications, or any other important information about this topic.

# %%
import spacy
from spacy.matcher import Matcher
import en_core_web_sm
nlp = en_core_web_sm.load()

# Retrieve the author's data, fill-in, and print
search_query = scholarly.search_keyword('regression')
author = next(search_query).fill()
# print(author)

top_100_articles=[pub.bib['title'] for pub in author.publications][0:99]
print(top_100_articles)
# nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)
# Add match ID "HelloWorld" with no callback and one pattern
# pattern = [{"LOWER": "hello"}, {"IS_PUNCT": True}, {"LOWER": "world"}]
pattern1 = [{"TEXT": {"REGEX": "algorith[m|ms]"}}]
pattern2 = [{"TEXT": {"REGEX": "mode[l|ls]"}}]
pattern3 = [{"TEXT": {"REGEX": "researc[h|hes]"}}]
pattern4 = [{"TEXT": {"REGEX": "metho[d|ds]"}}]
pattern5 = [{"TEXT": {"REGEX": "datase[t|ts]"}}]
pattern6 = [{"TEXT": {"REGEX": "applicatio[n|ns]"}}]
pattern7 = [{"TEXT": {"REGEX": "proble[m|ms]"}}]
matcher.add("algorithm",None,pattern1)
matcher.add("model",None,pattern2)
matcher.add("research",None,pattern3)
matcher.add("method",None,pattern4)
matcher.add("dataset",None,pattern5)
matcher.add("application",None,pattern6)
matcher.add("problem",None,pattern7)

for title in top_100_articles:
 doc = nlp(title)
 matches = matcher(doc)
#  print("\n matches are",matches)
 if matches:
  for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(title)
    print(match_id, string_id, start, end, span.text)
# Out:
# ['Geographically weighted regression: the analysis of spatially varying relationships', 'Geographically weighted regression', 'Geographically Weighted 36 Regression-Modelling Spatial Non-Stationarity', 'Geographically weighted regression: a method for exploring spatial nonstationarity', 'Quantitative geography: perspectives on spatial data analysis', 'Geographic data mining and knowledge discovery', 'Geographically weighted regression: a natural evolution of the expansion method for spatial data analysis', 'A mark 1 geographical analysis machine for the automated analysis of point data sets', 'Some notes on parametric significance tests for geographically weighted regression', 'Geographically weighted Poisson regression for disease association mapping', 'The geography of parameter space: an investigation of spatial non-stationarity', 'The British General Election of', 'Investigation of leukaemia clusters by use of a geographical analysis machine', 'Laser scanning for the environmenta
# ...

# %% [markdown]
# ## 2. Domain-specific information extraction
# For the legal case used in the data cleaning exercise: 01-05-1 Adams v Tanner.txt, use legalNLP to extract the following inforation from the text (if the information is not exist, just print None):

# %%
import pandas
import numpy
import lexnlp.extract.en.acts
import lexnlp.extract.en.amounts
import lexnlp.extract.en.citations
import lexnlp.extract.en.entities.nltk_re
import lexnlp.extract.en.conditions
import lexnlp.extract.en.constraints
import lexnlp.extract.en.copyright
import lexnlp.extract.en.courts
import lexnlp.extract.en.cusip
import lexnlp.extract.en.dates
import lexnlp.extract.en.distances
import lexnlp.extract.en.durations
import lexnlp.extract.en.money
import lexnlp.extract.en.percents
import lexnlp.extract.en.pii
import lexnlp.extract.en.ratios
import lexnlp.extract.en.regulations
import lexnlp.extract.en.trademarks
import lexnlp.extract.en.urls

text=open("01-05-1 Adams v Tanner.txt","r",encoding="utf8")
lines=text.readlines()
act=[]
amount,pll,ratio,regulation=[],[],[],[]
citation,percent,trademark=[],[],[]
company,url=[],[]
condition,duration,money=[],[],[]
distance,definition,date,constraint,copyright,cusip=[],[],[],[],[],[]

# court_df = pandas.read_csv("https://raw.githubusercontent.com/LexPredict/lexpredict-legal-dictionary/1.0.5/en/legal/us_courts.csv")
#     # Create config objects
# court_config_data = []
# for _, row in court_df.iterrows():
#   c = (row["Court ID"], row["Court Name"], 0, row["Alias"].split(";") if not pandas.isnull(row["Alias"]) else [])
#   court_config_data.append(c)

for data in lines:
#     print(data)
    act_content=lexnlp.extract.en.acts.get_act_list(data) 
    amount_content=list(lexnlp.extract.en.amounts.get_amounts(data,return_sources=True))
    citation_content=list(lexnlp.extract.en.citations.get_citations(data,return_source=False))
    company_content=list(lexnlp.extract.en.entities.nltk_re.get_companies(data))
    condition_content=list(lexnlp.extract.en.conditions.get_conditions(data))
    constraint_content=list(lexnlp.extract.en.constraints.get_constraints(data))
    copyright_content=list(lexnlp.extract.en.copyright.get_copyright(data,return_sources=False))
    cusip_content=list(lexnlp.extract.en.cusip.get_cusip(data))
    date_content=list(lexnlp.extract.en.dates.get_dates(data))
    definition_content=list(lexnlp.extract.en.definitions.get_definitions(data))
    distance_content=list(lexnlp.extract.en.distances.get_distances(data))
    duration_content=list(lexnlp.extract.en.durations.get_durations(data))
    money_content=list(lexnlp.extract.en.money.get_money(data))
    percent_content=list(lexnlp.extract.en.percents.get_percents(data))
    pll_content=list(lexnlp.extract.en.pii.get_pii(data))
    ratio_content=list(lexnlp.extract.en.ratios.get_ratios(data))
    regulation_content=list(lexnlp.extract.en.regulations.get_regulations(data))
    trademark_content=list(lexnlp.extract.en.trademarks.get_trademarks(data))
    url_data=list(lexnlp.extract.en.urls.get_urls(data))
#     print(cusip_content)
    
#     for entity, alias in lexnlp.extract.en.courts.get_courts(data, court_config_data):
#      print("entity=", entity)
#      print("alias=", alias)
#     print(citation_content)
#     print(amount_content)
    if act_content:
        act.append(act_content[0].get('value'))
    if amount_content:
        amount.append(amount_content)
    if citation_content:
        citation.append(citation_content)
    if company_content:
        company.append(company_content)
    if condition_content:
        condition.append(condition_content)
    if constraint_content:
        constraint.append(constraint_content)
    if copyright_content:
        copyright.append(copyright_content)
    if cusip_content:
        cusip.append(cusip_content[0].get('text'))
    if date_content:
        date.append(date_content)
    if definition_content:
        definition.append(definition_content)
    if distance_content:
        distance.append(distance_content)
    if duration_content:
        duration.append(duration_content)
    if money_content:
        money.append(money_content)
    if percent_content:
        percent.append(percent_content)
    if pll_content:
        pll.append(pll_content)
    if ratio_content:
        ratio.append(ratio_content)
    if regulation_content:
        regulation.append(regulation_content)
    if trademark_content:
        trademark.append(trademark_content)
    if url_data:
        url.append(url_data)
        
print("\nActs in File")
if act:
    print(act)
else:
    print("None")
print("\nAmounts in File")
if amount:
    print(amount)
else:
    print("None")
print("\nCitation in File")
if citation:
    print(citation)
else:
    print("None")
print("\nCompany in File")
if company:
    print(company)
else:
    print("None")
print("\nCondition in File")
if condition:
    print(condition)
else:
    print("None")
print("\nConstraint in File")
if constraint:
    print(constraint)
else:
    print("None")
print("\nCopyright in File")
if copyright:
    print(copyright)
else:
    print("None")
print("\nCusip in File")
if cusip:
    print(cusip)
else:
    print("None")
print("\nData in File")
if date:
    print(date)
else:
    print("None")
print("\nDefinition in File")
if definition:
    print(definition)
else:
    print("None")
print("\nDistance in File")
if distance:
    print(distance)
else:
    print("None")
print("\nDuration in File")
if duration:
    print(duration)
else:
    print("None")
print("\nMoney in File")
if money:
    print(money)
else:
    print("None")
print("\nPercent in File")
if percent:
    print(percent)
else:
    print("None")
print("\nPII in File")
if pll:
    print(pll)
else:
    print("None")
print("\nRatio in File")
if ratio:
    print(ratio)
else:
    print("None")
print("\nRegulation in File")
if regulation:
    print(regulation)
else:
    print("None")
print("\nTrademark in File")
if trademark:
    print(trademark)
else:
    print("None")
print("\nURL in File")
if url:
    print(url)
else:
    print("None")
# Out:
# ...
#
# Acts in File
# None
#
# Amounts in File
# ...
