# %%
#reading legal_case.tx file
import pandas as pd

data_file="Sample8 Project Lessons Learned.docx"
data=pd.read_csv(data_file,encoding='utf-8',error_bad_lines=False,names=['sentence'], lineterminator='\n')
#number of sentences
print("Number of Sentences :",len(data['sentence']))

#Lower casing
data['sentence']=data['sentence'].str.lower()
data['sentence'].head()

#Removing Punctuation
import string
data['sentence']=data['sentence'].str.replace('[{}]'.format(string.punctuation), '')
data['sentence'].head()

#Removing Stopwords
from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')
stop=stopwords.words('english')

data['sentence']=data['sentence'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
data['sentence'].head()

#frequent word removal
freq=pd.Series(' '.join(data['sentence']).split()).value_counts()[:10]
freq

freq=list(freq.index)

data['sentence']=data['sentence'].apply(lambda x:" ".join(x for x in x.split() if x not in freq))
data['sentence'].head()

#rare word removal
freq=pd.Series(' '.join(data['sentence']).split()).value_counts()[-10:]

freq=list(freq.index)
data['sentence']=data['sentence'].apply(lambda x:" ".join(x for x in x.split() if x not in freq))
data['sentence'].head()

#Spelling Correction
from textblob import TextBlob

data['sentence']=data['sentence'].apply(lambda x: TextBlob(x).correct())

#stemming
from nltk.stem import PorterStemmer
st=PorterStemmer()

data['sentence']=data['sentence'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
data['sentence'].head()

#Lemmetization
from textblob import Word

import nltk
nltk.download('wordnet')
data['sentence']=data['sentence'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data['sentence'].head()

#dropping empty rows
# sentence=data["sentence"] != ""
# data=data[sentence]
# data=data.reset_index(inplace=False)
# data['sentence'].head()

#saving the formatted sentences to "Formatted_sentences.txt"

data['sentence'].to_csv("Formatted_potential_improvements_sample8.txt",header=False,index=False,decode="utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 0: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-1d02967ca07e> in <module>
#       3
#       4 data_file="Sample8 Project Lessons Learned.docx"
# ----> 5 data=pd.read_csv(data_file,encoding='utf-8',error_bad_lines=False,names=['sentence'], lineterminator='\n')
#       6 #number of sentences
#       7 print("Number of Sentences :",len(data['sentence']))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 0: invalid continuation byte
